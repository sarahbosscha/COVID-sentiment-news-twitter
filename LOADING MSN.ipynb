key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1093/cid/ciaa461?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1101/2020.04.08.20057794?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.7326/l20-0175?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1016/j.ijid.2020.03.017?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1001/jama.2020.6775?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1016/s0140-6736(20)30817-5?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1101/2020.04.06.20050575?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1016/s0140-6736(20)30460-8?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1056/nejmoa2004500?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.3760/cma.j.cn112338-20200221-00144?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.3760/cma.j.cn112338-20200221-00144?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1101/2020.04.10.20060699?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1007/s10072-020-04391-9?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1056/nejmc2009324?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1177/0194599820926464?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.3760/cma.j.issn.1001-0939.2020.03.009?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1101/2020.02.12.20022434?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1101/2020.02.12.20022434?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1128/jvi.64.3.1407-1409.1990?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.3201/eid1011.040797_02?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.3201/eid1011.040797_02?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1056/nejme2007263?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1161/circresaha.120.317055?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1101/2020.03.15.20036368?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1148/radiol.2020200463?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1080/22221751.2020.1727299?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1016/j.ajogmf.2020.100111?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1080/10255842.2020.1759560?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1001/jama.2020.4621?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1002/bjs.11674?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.2807/1560-7917.es.2020.25.3.2000045?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1038/s41585-020-0319-7?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1002/jmv.25711?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1001/jamacardio.2020.1105?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.2196/18936?key=bfc9115e2490100d074ded6a3a2cb845']

# %%
def get_json_from_page(url):
    res = requests.get(url)
    html_page = res.content

    soup = BeautifulSoup(html_page, "lxml")

    dictionary = json.loads(res.content)
    return dictionary

def get_all_news(dictionary):
    url_news = []
    for news in dictionary['posts']['news']:
        if news['name'] == 'MSN':
            url = news['url']
            url_news.append(url)
        if news['name'] == 'msn':
            url = news['url']
            url_news.append(url)
#     print(url_tweets)
    return url_news

# %%
#Receive all url's of the news articles

list = all_msn
for i in list:
    dictionary = get_json_from_page(i)
    url_news = []
    for news in dictionary['posts']['news']:
        if news['author']['name'] == 'MSN':
            url = news['url']
            print(url)
            url_news.append(url)
        if news['author']['name'] == 'msn':
            url = news['url']
            print(url)
            url_news.append(url)
#     print(url_tweets)
    
print(url_news)

    #print(dictionary)
#     get_all_news(dictionary)
# Out:
# http://ct.moreover.com/?a=41892959666&p=1pl&v=1&x=6XdmvvvE2x6DQSIo4pKL9A
# http://ct.moreover.com/?a=41964626738&p=1pl&v=1&x=OnPpAJ_qT1QPoMQeK5B1YA
# http://ct.moreover.com/?a=41994261107&p=1pl&v=1&x=eRt7Po2KFowe6MKiIT8sQw
# http://ct.moreover.com/?a=42139865452&p=1pl&v=1&x=3Ahmv_Z8OTPG2RMH6FAa-g
# http://ct.moreover.com/?a=41674062144&p=1pl&v=1&x=n3kZGxRfY8_MYd0tk7nlZg
# http://ct.moreover.com/?a=41671844587&p=1pl&v=1&x=DT_K84WMHaoOHYil-gwQDw
# http://ct.moreover.com/?a=41672657269&p=1pl&v=1&x=1wMkyoeRStLR5cE4mXwyCQ
# http://ct.moreover.com/?a=41764217121&p=1pl&v=1&x=DV39qRfneCC7Zp0ZjYyGUw
# http://ct.moreover.com/?a=41919554994&p=1pl&v=1&x=esBuUbpS2gT-SE793HLx8g
# http://ct.moreover.com/?a=42039508812&p=1pl&v=1&x=ZVXoOZ9KCA8WhidL_bCUAQ
# http://ct.moreover.com/?a=42036456998&p=1pl&v=1&x=95tPHknd4RC50gn7P31IGQ
# http://ct.moreover.com/?a=42037313518&p=1pl&v=1&x=dJpRUBb63_Sl11eXlCesfA
# http://ct.moreover.com/?a=42047087917&p=1pl&v=1&x=inKUd8C-5qvl8X27RMIXvw
# ...

# %%
url = 'https://www.msn.com/en-sg/lifestyle/lifestylegeneral/everything-you-need-to-know-about-coronavirus-causing-blood-clots/ar-BB13ov98?li=BBr8OIU&srcref=rss'

# %%
# Empty lists for content, links and titles
news_contents = []
list_links = []
list_titles = []

# Getting the link of the article
link = url
list_links.append(link)

# # Getting the title
# title = coverpage_news[n].find('a').get_text()
# list_titles.append(title)

# Reading the content (it is divided in paragraphs)
article = requests.get(link)
article_content = article.content
soup_article = BeautifulSoup(article_content, 'html.parser')
body = soup_article.find_all('section', class_='articlebody')
x = body[0].find_all('p')
x = body[0].ignore_all('div')

# Unifying the paragraphs
list_paragraphs = []
for p in np.arange(0, len(x)):
    paragraph = x[p].get_text()
    list_paragraphs.append(paragraph)
    final_article = " ".join(list_paragraphs)

news_contents.append(final_article)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-3b402e9355bb> in <module>
#      17 soup_article = BeautifulSoup(article_content, 'html.parser')
#      18 body = soup_article.find_all('section', class_='articlebody')
# ---> 19 x = body[0].find_all('p')
#      20 x = body[0].ignore_all('div')
#      21
#
# IndexError: list index out of range

# %%
# Empty lists for content, links and titles
news_contents = []
list_titles = []

for link in all_msn:
    title = requests.get(link)
    title_content = title.content
    soup_article = BeautifulSoup(title_content, 'html.parser')
    body = soup_article.find_all('header', itemprop='collection-headline-flex')
    y = body[0].find_all('h1')

    # Unifying the paragraphs
    list_paragraphs = []
    for p in np.arange(0, len(y)):
        paragraph = y[p].get_text()
        list_paragraphs.append(paragraph)
        final_title = " ".join(list_paragraphs)
        print('TITLE:',final_title)
    list_titles.append(final_title)


    # Reading the content (it is divided in paragraphs)
    article = requests.get(link)
    article_content = article.content
    soup_article = BeautifulSoup(article_content, 'html.parser')
    body = soup_article.find_all('section', class_='articlebody')
    x = body[0].find_all('p')

    # Unifying the paragraphs
    list_paragraphs = []
    for p in np.arange(0, len(x)):
        paragraph = x[p].get_text()
        list_paragraphs.append(paragraph)
        final_article = " ".join(list_paragraphs)
        print('ARTICLE:', final_article)

    news_contents.append(final_article)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-b7260d58d1bb> in <module>
#       8     soup_article = BeautifulSoup(title_content, 'html.parser')
#       9     body = soup_article.find_all('header', itemprop='collection-headline-flex')
# ---> 10     y = body[0].find_all('h1')
#      11
#      12     # Unifying the paragraphs
#
# IndexError: list index out of range

# %%
print(final_article)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-41b3ee3b5707> in <module>
# ----> 1 print(final_article)
#
# NameError: name 'final_article' is not defined

# %%
print(final_title)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-b5e35f96815b> in <module>
# ----> 1 print(final_title)
#
# NameError: name 'final_title' is not defined
