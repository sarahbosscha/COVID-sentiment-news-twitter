# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time
import json

# %% [markdown]
# https://api.altmetric.com/v1/fetch/doi/10.1148/radiol.2020201544?key=bfc9115e2490100d074ded6a3a2cb845

# %%
#API list of DOI's of COVID-19 articles, written >2020 and have an citation of this journal

all_medscape_API = ['https://api.altmetric.com/v1/fetch/doi/10.1016/j.cgh.2020.04.002?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1136/bmj.m1676?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1126/science.abc1669?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.2214/ajr.20.22927?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1016/s1470-2045(20)30265-5?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1111/jebm.12381?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1101/2020.03.11.20031096?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1016/j.jacc.2020.03.031?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1038/s41591-020-0819-2?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1038/s41591-020-0819-2?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1101/2020.04.23.20076042?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1007/s00134-020-05996-6?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1056/nejmc2009787?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1016/j.jinf.2020.02.028?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1016/j.jinf.2020.02.028?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1001/jama.2020.4742?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1056/nejmc2001899?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1164/rccm.202003-0736le?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1126/science.abb7498?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1007/s00405-020-05965-1?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1007/s00134-020-05993-9?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1001/jamapsychiatry.2020.0894?key=bfc9115e2490100d074ded6a3a2cb845', 
'https://api.altmetric.com/v1/fetch/doi/10.1177/0141076820921107?key=bfc9115e2490100d074ded6a3a2cb845',
'https://api.altmetric.com/v1/fetch/doi/10.1016/j.jaccas.2020.04.016?key=bfc9115e2490100d074ded6a3a2cb845',
'https://api.altmetric.com/v1/fetch/doi/10.1056/nejmp2003539?key=bfc9115e2490100d074ded6a3a2cb845',
'https://api.altmetric.com/v1/fetch/doi/10.1016/s1473-3099(20)30367-4?key=bfc9115e2490100d074ded6a3a2cb845']

# %%
def get_json_from_page(url):
    res = requests.get(url)
    html_page = res.content

    soup = BeautifulSoup(html_page, "lxml")

    dictionary = json.loads(res.content)
    return dictionary

def get_all_news(dictionary):
    url_news = []
    for news in dictionary['posts']['news']:
        if news['name'] == 'medsape':
            url = news['url']
            print(dictionary['doi'])
            url_news.append(url)
        if news['name'] == 'medscape':
            url = news['url']
            url_news.append(url)
#     print(url_tweets)
    return url_news

# %%
#Receive all url's of the news articles

list = all_medscape_API
for i in list:
    dictionary = get_json_from_page(i)
#     print(dictionary)
    url_news = []
#     print(dictionary['doi'])
    for news in dictionary['posts']['news']:
#         print(news)
        if news['author']['name'] == 'Medscape':
            url = news['url']
            print(url)
            url_news.append(url)
# Out:
# http://ct.moreover.com/?a=41942584426&p=1pl&v=1&x=oImk66EDMk0afy_6qRV4Kw
# http://ct.moreover.com/?a=42013930925&p=1pl&v=1&x=iyP7aXEhkda-hEd_Ws9t8A
# http://ct.moreover.com/?a=42064432347&p=1pl&v=1&x=7Zo6xOQ-_GF1zcjgpn_Gkw
# http://ct.moreover.com/?a=42064510604&p=1pl&v=1&x=IzcARYNVKQwNOGA3jISD5w
# http://ct.moreover.com/?a=41598836239&p=1pl&v=1&x=Vcnq0S94YyNFgUw-sLfY6w
# http://ct.moreover.com/?a=41599279912&p=1pl&v=1&x=m4zmYyueGwum5akUTyZfjQ
# http://ct.moreover.com/?a=42085880624&p=1pl&v=1&x=Fw7a21cWOiMvbDYYXnaFtA
# http://ct.moreover.com/?a=41675340392&p=1pl&v=1&x=g4XTnD3Kylkc4OK2UJig3g
# http://ct.moreover.com/?a=41677584890&p=1pl&v=1&x=b_xMJLNDBGvM7Zqv9sfKbA
# http://ct.moreover.com/?a=42347969285&p=1pl&v=1&x=F84uPej3U1LaFY1ftBpeNA
# http://ct.moreover.com/?a=41724115414&p=1pl&v=1&x=HvLcNMKKaIJ6T65SywUTXQ
# http://ct.moreover.com/?a=42065919986&p=1pl&v=1&x=SDlrYZNmnBbeyVXWH_LhHg
# http://ct.moreover.com/?a=41659865963&p=1pl&v=1&x=JcWOChtUBM5Uj20PkQQDkQ
# ...

# %%
yahoo_urls = ['http://ct.moreover.com/?a=41755372192&p=1pl&v=1&x=RuAlQWJ6lGXSUx5pUVNaAA', 
              'http://ct.moreover.com/?a=41703246219&p=1pl&v=1&x=Z8p60UAckQddUZUdQlO58g' , 
              'http://ct.moreover.com/?a=41698558444&p=1pl&v=1&x=GIQjNpxs2OHfJsgpuXavRg' , 
                'http://ct.moreover.com/?a=41644809759&p=1pl&v=1&x=Fqc9-mmRkmExpEWXhHwDlg' , 
                'http://ct.moreover.com/?a=42034821341&p=1pl&v=1&x=_S17G0mvUJg75Gpa2uf4OA' , 
                'http://ct.moreover.com/?a=41793346332&p=1pl&v=1&x=1HIhN819Il8B_GSNKG9jAA' , 
                'http://ct.moreover.com/?a=41638835605&p=1pl&v=1&x=xWn5t5l_XXktLFsfUwdQIg' , 
                'http://ct.moreover.com/?a=41715599104&p=1pl&v=1&x=DOnJjXBogveGdLCBFW84pw' , 
                'http://ct.moreover.com/?a=41658306061&p=1pl&v=1&x=B4UcDSz2ptiMll8i68LHiw' , 
                'http://ct.moreover.com/?a=42086341517&p=1pl&v=1&x=D-Ow9V65a6WMyEmKbshB6Q' , 
                'http://ct.moreover.com/?a=41943761542&p=1pl&v=1&x=XH5j6wPV8WGNq1slojrHfA', 
                'http://ct.moreover.com/?a=41462901617&p=1pl&v=1&x=hrAHtA3Ejd_7dZtau8-AYg', 
                'http://ct.moreover.com/?a=42047811953&p=1pl&v=1&x=WdP9YWdTlS-CfmG5bNmX4g', 
                'http://ct.moreover.com/?a=42049562543&p=1pl&v=1&x=mMiRLx-NOx48pAUzsnjr3Q', 
                'http://ct.moreover.com/?a=41770545565&p=1pl&v=1&x=d2fBR3QXJ2bNlHEKogMSyw', 
                'http://ct.moreover.com/?a=41827551843&p=1pl&v=1&x=mzMof2d477F8cUI4N3oDOw', 
                'http://ct.moreover.com/?a=41894613456&p=1pl&v=1&x=Ep1rig17pLiqSP4XEEwuVg', 
                'http://ct.moreover.com/?a=41673493330&p=1pl&v=1&x=y9HtrAMVrztBHb4wMmBi2g', 
                'http://ct.moreover.com/?a=41696976528&p=1pl&v=1&x=_Ioiuk-zxb7NBU9sgNuK_A', 
                'http://ct.moreover.com/?a=41819359953&p=1pl&v=1&x=KvvXGQaDdT8mCbka0JAnow', 
                'http://ct.moreover.com/?a=41820868161&p=1pl&v=1&x=s1LbGjbGHcyERwVwtYXUFw', 
                'http://ct.moreover.com/?a=41605466822&p=1pl&v=1&x=uO_lcgdUnCzQVORNKDiziQ', 
                'http://ct.moreover.com/?a=41616397820&p=1pl&v=1&x=nPmiEp0OknGN4eTBU0Js2Q', 
                'http://ct.moreover.com/?a=41635169387&p=1pl&v=1&x=Lc80La7WIkB4gCLFIDRNSg', 
                'http://ct.moreover.com/?a=41647068043&p=1pl&v=1&x=zuTxsMygDVXgj2jXEkPM-A', 
                'http://ct.moreover.com/?a=41665956812&p=1pl&v=1&x=O73a4fiX6nKdQBea4sKajg', 
                'http://ct.moreover.com/?a=41718525982&p=1pl&v=1&x=TftbibMMBZCD3MThNyC_Kw', 
                'http://ct.moreover.com/?a=41755936322&p=1pl&v=1&x=UA3AmxJZE7ww4U633JTMlw', 
                'http://ct.moreover.com/?a=41798112682&p=1pl&v=1&x=tH6Bddkgl4YctpUBOQs72w', 
                'http://ct.moreover.com/?a=41819196413&p=1pl&v=1&x=6x1tBZSh0g9-j4Jilv7dYQ', 
                'http://ct.moreover.com/?a=41491329528&p=1pl&v=1&x=4iRrQCMvQbQmPU9x3bdAow', 
                'http://ct.moreover.com/?a=41596357860&p=1pl&v=1&x=WSEvBYi8LHigOc7bhSAV4Q', 
                'http://ct.moreover.com/?a=41648146800&p=1pl&v=1&x=QgkSpgFfMPDfNWECzkoV8Q', 
                'http://ct.moreover.com/?a=41653641139&p=1pl&v=1&x=ZWbCefakawMb5UxaBxwUNQ', 
                'http://ct.moreover.com/?a=41656715404&p=1pl&v=1&x=CKqUM0nYrqPg7LwLpaQQtQ', 
                'http://ct.moreover.com/?a=41720962300&p=1pl&v=1&x=LQt_ZiHDEjHzDjC5lUFonw', 
                'http://ct.moreover.com/?a=41554381509&p=1pl&v=1&x=z7wFr9uBdnpUP5DsGhrQNQ', 
                'http://ct.moreover.com/?a=42086341517&p=1pl&v=1&x=D-Ow9V65a6WMyEmKbshB6Q', 
                'http://ct.moreover.com/?a=41240503460&p=1pl&v=1&x=Pic-tumrRAOB1MEZ2rJyBw', 
                'http://ct.moreover.com/?a=41259532208&p=1pl&v=1&x=ktLC7Q3gn1JnNI8qlonXow', 
                'http://ct.moreover.com/?a=41268733891&p=1pl&v=1&x=P0z-WCymCVimLn_0tg4xog', 
                'http://ct.moreover.com/?a=41366764814&p=1pl&v=1&x=XFfzuLe3spa3ZMnU6okr0A', 
                'http://ct.moreover.com/?a=41987961582&p=1pl&v=1&x=12oeh65ARptrjK4vQJV0NA', 
                'http://ct.moreover.com/?a=41996275497&p=1pl&v=1&x=B-d5HJsjLOwGEVVegZCSuA']

# %%
# Request
r1 = requests.get(url)
r1.status_code

# We'll save in coverpage the cover page content
coverpage = r1.content

# Soup creation
soup1 = BeautifulSoup(coverpage, 'html.parser')

# News identification
coverpage_news = soup1.find_all('h3', class_='fc-item__title')
len(coverpage_news)

# %%
# Empty lists for content, links and titles
news_contents = []
list_titles = []

for link in yahoo_urls:
    title = requests.get(link)
    title_content = title.content
    soup_article = BeautifulSoup(title_content, 'html.parser')
    body = soup_article.find_all('header', class_='canvas-header')
    y = body[0].find_all('h1')

    # Unifying the paragraphs
    list_paragraphs = []
    for p in np.arange(0, len(y)):
        paragraph = y[p].get_text()
        list_paragraphs.append(paragraph)
        final_title = " ".join(list_paragraphs)
        print('TITLE:',final_title)
    list_titles.append(final_title)


    # Reading the content (it is divided in paragraphs)
    article = requests.get(link)
    article_content = article.content
    soup_article = BeautifulSoup(article_content, 'html.parser')
    body = soup_article.find_all('article', itemprop='articleBody')
    x = body[0].find_all('p')

    # Unifying the paragraphs
    list_paragraphs = []
    for p in np.arange(0, len(x)):
        paragraph = x[p].get_text()
        list_paragraphs.append(paragraph)
        final_article = " ".join(list_paragraphs)
        print('ARTICLE:', final_article)

    news_contents.append(final_article)
# Out:
# TITLE: The Payoff from the Pain: Trillions in Benefits Seen from Social Distancing to Slow Coronavirus
# ARTICLE: Click here to read the full article.
# ARTICLE: Click here to read the full article.  The costs of slowing the spread of coronavirus are enormous. Large sections of the economy have ground to a halt. The stock market has crashed. Unemployment claims surged by more than 3 million last week alone. Congress was forced to pass a $2.2 trillion rescue package — and it will likely need to add to that as the budgets of states on the front lines begin to crater. President Trump has bellyached “we cannot let the cure be worse than the problem itself” — though he has now blessedly backed off plans to reopen the country by Easter.
# ...

# %%
print(news_contents)
# Out:
# ['Doctors around the world are trying to make sense of the wide range of effects that COVID-19 — the disease caused by the novel coronavirus — can have on the body.\xa0 Most people associate the infection with respiratory symptoms — fever, cough, fatigue. But many patients who contract the virus experience neurological symptoms such as headache and dizziness, as well as heart issues, kidney complications and, most recently, blood clotting (also called coagulation).\xa0 The clots have taken various shapes and forms in different patients. In milder cases, the clots — which appear to be scattered throughout the body — have been linked to rashes or swollen, red toes (recently deemed “COVID toes”). In more severe cases, the clots can block an artery and cause a pulmonary embolism\xa0or trigger a heart attack or stroke. It’s unclear why so many patients admitted to the hospital with COVID-19 are developing clots. One study found that nearly a third of COVID-19 patients in intensive care ha
# ...

# %%
print(list_titles)
# Out:
# ['Everything You Need To Know About Coronavirus Causing Blood Clots']
